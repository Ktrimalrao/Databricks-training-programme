# %%
dbutils.notebook.help()

# %%
dbutils.notebook.run("./ChiledNOtebook", timeout_seconds=15)

# %%
execution_status = dbutils.notebook.run("./ChiledNOtebook", timeout_seconds=100, arguments={
    "environment": "Testing"
})
execution_status
