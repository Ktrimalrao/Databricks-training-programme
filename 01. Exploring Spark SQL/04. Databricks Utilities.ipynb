# %%
dbutils.widgets.help()

# %%
dbutils.widgets.combobox("top_n_records",
                         defaultValue="1",
                         choices=["1","2","3","4"],
                         label="Top N Records")

# %%
dbutils.widgets.get("top_n_records")
